# %% [markdown]
# ## Sets

# %% [markdown]
# ## Q1

# %% [markdown]
# ![image.png](attachment:2e5de8ef-ff2c-42d8-9349-905fb9d01a77.png)

# %%
emails = ["alice@email.com", "bob@email.com", "alice@email.com", "charlie@email.com", "bob@email.com"]
emails = list(set(emails))
emails
# Out:
# ['alice@email.com', 'bob@email.com', 'charlie@email.com']

# %% [markdown]
# ## Q2

# %% [markdown]
# ![image.png](attachment:124a3f85-9a6c-4a82-89d3-4ac282fa3e2f.png)

# %%
user_a_friends = {"Alice", "Bob", "Charlie", "David"}
user_b_friends = {"Charlie", "David", "Eve", "Frank"}
mutual_friends = user_a_friends.intersection(user_b_friends)
mutual_friends
# Out:
# {'Charlie', 'David'}

# %% [markdown]
# ## Q3

# %% [markdown]
# ![image.png](attachment:26b2e1cf-8c79-4e58-86e3-948e7ef49d65.png)

# %%
fridge_inventory = {"eggs", "milk", "butter", "cheese", "bread"}
recipe_needs = {"milk", "eggs", "flour", "sugar"}
buy = recipe_needs.difference(fridge_inventory)
buy
# Out:
# {'flour', 'sugar'}
